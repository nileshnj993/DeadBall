# %%
from statsbombpy import sb

# %%
matches = sb.matches(
    competition_id=11, 
    season_id=90)
# Out:
# /Users/naintarasingh/miniconda3/envs/DeadBall/lib/python3.14/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
matches.columns
# Out:
# Index(['match_id', 'match_date', 'kick_off', 'competition', 'season',
#        'home_team', 'away_team', 'home_score', 'away_score', 'match_status',
#        'match_status_360', 'last_updated', 'last_updated_360', 'match_week',
#        'competition_stage', 'stadium', 'referee', 'home_managers',
#        'away_managers', 'data_version', 'shot_fidelity_version',
#        'xy_fidelity_version'],
#       dtype='str')

# %%
events = sb.events(match_id=3773386)
# Out:
# /Users/naintarasingh/miniconda3/envs/DeadBall/lib/python3.14/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(

# %%
events.columns
# Out:
# Index(['50_50', 'bad_behaviour_card', 'ball_receipt_outcome',
#        'ball_recovery_offensive', 'ball_recovery_recovery_failure',
#        'carry_end_location', 'clearance_aerial_won', 'clearance_body_part',
#        'clearance_head', 'clearance_left_foot', 'clearance_right_foot',
#        'counterpress', 'dribble_nutmeg', 'dribble_outcome', 'dribble_overrun',
#        'duel_outcome', 'duel_type', 'duration', 'foul_committed_advantage',
#        'foul_committed_card', 'foul_committed_offensive',
#        'foul_committed_type', 'foul_won_advantage', 'foul_won_defensive',
#        'goalkeeper_body_part', 'goalkeeper_end_location', 'goalkeeper_outcome',
#        'goalkeeper_position', 'goalkeeper_technique', 'goalkeeper_type', 'id',
#        'index', 'interception_outcome', 'location', 'match_id', 'minute',
#        'miscontrol_aerial_won', 'off_camera', 'out', 'pass_aerial_won',
#        'pass_angle', 'pass_assisted_shot_id', 'pass_body_part', 'pass_cross',
# ...

# %%
events[['play_pattern', 'shot_statsbomb_xg']].dropna().count()
# Out:
# play_pattern         29
# shot_statsbomb_xg    29
# dtype: int64

# %%
events[['play_pattern', 'shot_outcome']].dropna().count()
# Out:
# play_pattern    29
# shot_outcome    29
# dtype: int64

# %%
events[['play_pattern', 'shot_statsbomb_xg', 'shot_outcome', 'shot_type']].dropna()
# Out:
#         play_pattern  shot_statsbomb_xg shot_outcome  shot_type
# 3805   From Throw In           0.200969        Off T  Open Play
# 3806    Regular Play           0.096384        Saved  Open Play
# 3807   From Throw In           0.098879        Off T  Open Play
# 3808  From Free Kick           0.078938      Blocked  Free Kick
# 3809    Regular Play           0.976192         Goal  Open Play
# 3810  From Free Kick           0.203073        Off T  Open Play
# 3811  From Free Kick           0.095015      Blocked  Free Kick
# 3812  From Free Kick           0.017764        Off T  Free Kick
# 3813  From Goal Kick           0.112452        Saved  Open Play
# 3814    Regular Play           0.054103        Saved  Open Play
# 3815   From Throw In           0.030959        Saved  Open Play
# 3816   From Throw In           0.085421        Off T  Open Play
# 3817  From Free Kick           0.044592        Off T  Free Kick
# 3818  From Free Kick           0.291415         Goal  Open Play
# ...

# %%
players = sb.pla
