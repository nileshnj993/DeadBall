# %%
# !pip install pexpect
# !pip install statsbombpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().system('pip install pexpect')
#       2 get_ipython().system('pip install statsbombpy')
#
# File /opt/miniconda3/envs/DeadBall/lib/python3.13/site-packages/ipykernel/zmqshell.py:788, in ZMQInteractiveShell.system_piped(self, cmd)
#
# ModuleNotFoundError: No module named 'pexpect'

# %%
from statsbombpy import sb

competitions = sb.competitions()
df_la_liga = competitions[competitions['competition_name']=='Premier League']
df_la_liga = competitions[competitions['season_name']=='2015/2016']
print(df_la_liga)
print(df_la_liga.shape[0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from statsbombpy import sb
#       2
#       3 competitions = sb.competitions()
#       4 df_la_liga = competitions[competitions['competition_name']=='Premier League']
#
# ModuleNotFoundError: No module named 'statsbombpy'
